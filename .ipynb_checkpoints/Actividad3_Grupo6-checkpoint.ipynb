# %% [markdown]
# ## <center>Actividad 3 - Análisis exploratorio de datos + Machine Learning</center>

# %% [markdown]
# Estudiantes: Rubén Martínez Gormaz | Samuel Fernando Méndez | Ruoyan Zhang | Lian Salmerón López

# %% [markdown]
# ## Grupo 6

# %% [markdown]
# En esta actividad se pide realizar un análisis profundo sobre un conjunto de datos de un tema de negocio, para llevar a cabo un procesamiento de la información y entrenar un modelo de aprendizaje automático, que consiga predecir los siguientes valores del conjunto de datos.

# %% [markdown]
# Para esta activiad se ha escogido el tema del precio de los combustibles en España durante el 2022.

# %% [markdown]
# ## <center><u>Instalación de librerías</u></center>

# %% [markdown]
# Las librerías utilizadas para esta investigación son las siguientes, si no se tiene alguna de ellas, debe ejecutar la siguiente línea.

# %%
## Dejar para librerias nuevas que utilicemos

# %% [markdown]
# Una vez instaladas, se importan al proyecto.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# - La librería <b>pandas</b> se especializa en la manipulación y análisis de datos. Ofrece estructuras de datos y operaciones para manipular tablas numéricas y series temporales. <br>
# - La librería <b>numpy</b> ofrece la posibilidad de crear vectores y matrices grandes multidimensionales, junto con una gran colección de funciones matemáticas.<br>
# - La libería <b>os</b>  provee una manera versátil de usar funcionalidades dependientes del sistema operativo.

# %% [markdown]
# ## <center><u>Desarrollo</u></center>

# %% [markdown]
# Primero se deben cargar los ficheros descargados, sin embargo éstos se encuentran en un formato diferente (<i>.parquet</i>), para trabajar con ellos de una manera más sencilla, se transforman a documentos <i>.csv</i>.

# %%
# Se realiza en un rango de 0 a 17, ya que existen 17 documentos de datos.
for fichero_parquet in range(0, 17):
    # Si el fichero no supera el noveno documento
    if fichero_parquet > 9:
        parquet = pd.read_parquet('spanish_gas_prices_00000000000'+str(fichero_parquet)+'.parquet')
        parquet.to_csv('spanish_gas_prices_00000000000'+str(fichero_parquet)+'.csv')
        print("hola" + fichero_parquet)
    # Si el fichero supera el noveno documento
    else:
        parquet = pd.read_parquet('spanish_gas_prices_0000000000'+str(fichero_parquet)+'.parquet')
        parquet.to_csv('spanish_gas_prices_0000000000'+str(fichero_parquet)+'.csv')
        print("adios" + fichero_parquet)

# %% [markdown]
# Una vez transformados todos los documentos al formato que se desea, se empieza a cargar todos los ficheros.

# %% [markdown]
# ### Carga de datos

# %% [markdown]
# Para cargar los datos que se encuentran en los csv, se cargarán de uno a uno los 17 documentos, para después unirlos en una misma tabla y trabajar con ellos. Por lo tanto se realizarán los filtros necesarios (en este caso obtener el precio de la gasolina para madrid durante el 2022). <br>
# Todos los archivos mantienen una misma estructura por lo que se explicarán las características con la ayuda del priemr .csv

# %% [markdown]
# ## CSV 00

# %%
# Se carga el primer csv
df_gasoline_00 = pd.read_csv('D:\IA\spanish_gas_prices_000000000000.csv')

# %%
df_gasoline_00.shape
# Out:
# (3043717, 32)

# %% [markdown]
# Todos los documentos tendrán 32 columnas, con un número de filas que puede variar.

# %%
df_gasoline_00.head()
# Out:
#    station_id                              name  \
# 0        4368  ESTACIÓN DE SERVICIO LOS VIÑEDOS
# 1        3468                             CEPSA
# 2        7229                            BP OIL
# 3        7421                            REPSOL
# 4         726                            REPSOL
#
#                                address                       town  zip_code  \
# 0       CARRETERA DE LAS MESAS KM. 005  VILLARROBLEDO                  2600
# 1  AVENIDA DOCTOR GREGORIO MARAÑÓN, 14  TORREVIEJA                     3180
# 2             CARRETERA N-IV KM. 536,7  SEVILLA                       41020
# 3                   AU AP-7  224,00  I  TORREMOLINOS                  29620
# 4    CARRETERA CAMBADOS-NOGUEIRA KM. 8  VILANOVA DE AROUSA            36620
#
#    longitude   latitude road_side restriction sender  ... gasoline_98E10  \
# 0  -2.617083  39.272250         N           P     dm  ...            NaN
# 1  -0.687444  37.977278         I           P     dm  ...            NaN
# 2  -5.972472  37.337278         N           P     dm  ...            NaN
# 3  -4.527250  36.613611         I           P     dm  ...            NaN
# 4  -8.756111  42.536417         D           P     dm  ...            NaN
#
#    diesel_A  diesel_B  diesel_premium bioetanol biodiesel lpg cng  lng  \
# 0     1.879     1.459           1.969       NaN       NaN NaN NaN  NaN
# 1     1.899       NaN           1.965       NaN       NaN NaN NaN  NaN
# 2     1.859       NaN           1.939       NaN       NaN NaN NaN  NaN
# 3     1.929       NaN           2.019       NaN       NaN NaN NaN  NaN
# 4     1.979     1.619           2.019       NaN       NaN NaN NaN  NaN
#
#    hydrogen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# La tabla resultante resulta ser demasiado grande para visualizar, por lo tanto se explicarán todas las columnas que aparecen en el documento.

# %%
df_gasoline_00.columns
# Out:
# Index(['station_id', 'name', 'address', 'town', 'zip_code', 'longitude',
#        'latitude', 'road_side', 'restriction', 'sender', 'schedule',
#        'region_id', 'province_id', 'municipality_id', 'region_name',
#        'province_name', 'municipality_name', 'date', 'gasoline_95E5',
#        'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
#        'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
#        'biodiesel', 'lpg', 'cng', 'lng', 'hydrogen'],
#       dtype='object')

# %% [markdown]
# ### Datos

# %% [markdown]
# A continunación se explicarán todos los datos del csv
# <ul>
#     <li>station_id - El identificador de las estaciones de servicio.</li>
#     <li>name - Nombre de la estación de servicio.</li>
#     <li>address - Dirección de dónde se encuentra la estación de servicio.</li>
#     <li>town - Ciudad en la que se encuentra la estación de servicio.</li>
#     <li>zip_code - Código postal de la región en la que se halla la la estación de servicio.</li>
#     <li>longitude - Coordenada geográfica que equivale al eje X para indicar la posición de la estación de servicio.</li>
#     <li>latitude - Coordenada geográfica que equivale al eje Y para indicar la posición de la estación de servicio.</li>
#     <li>road_side - El lado de la carretera al que se encuentra la estación de servicio (N) Ninguna, (D) Derecha, (I) Izquierda.</li>
#     <li>restriction - Indica si la estación es de acceso público (P) o se encuentra restringido (R).</li>
#     <li>sender - El distribuidor, pudiendo ser un operador mayorista (OM) o un distribuidor menor (dm).</li>
#     <li>schedule - Programa de horarios en los que se encuentra disponible la estación de servicio.</li>
#     <li>region_id - Identificador de la región a la que pertenece la estación.</li>
#     <li>province_id - Identificador de la provincia a la que pertenece la estación.</li>
#     <li>municipality_id - Identificador del municipio al que pertenece la estación.</li>
#     <li>region_name - Nombre de la región a la que pertenece la estación.</li>
#     <li>province_name - Nombre de la provincia a la que pertence la estación.</li>
#     <li>municipality_name - Nombre del municipio al que pertence la estación.</li>
#     <li>date - Fecha en la que se tomaron los datos de los diferentes carburantes.</li>
#     <li>gasoline_95E5 - Precio de la gasolina 95E5 para una cierta fecha.</li>
#     <li>gasoline_95E5_premium - Precio de la gasolina 95E5 premium para una cierta fecha.</li>
#     <li>gasoline_95E10 - Precio de la gasolina 95E10 para una cierta fecha.</li>
#     <li>gasoline_98E5 - Precio de la gasolina 98E5 para una cierta fecha.</li>
#     <li>gasoline_98E10 - Precio de la gasolina 98E10 para una cierta fecha.</li>
#     <li>diesel_A - Precio del diesel A para una cierta fecha.</li>
#     <li>diesel_B - Precio del diesel B para una cierta fecha.</li>
#     <li>diesel_premium - Precio del diesel premium para una cierta fecha.</li>
#     <li>bioetanol - Precio del bioetanol para una cierta fecha.</li>
#     <li>biodiesel - Precio del biodiesel para una cierta fecha.</li>
#     <li>lpg - Precio para el lpg (Gas licuado del petróleo) para una cierta fecha.</li>
#     <li>cng - Precio para el cng (Gas natural comprimido) para una cierta fecha.</li>
#     <li>lng - Precio para el lng (Gas natural licuado) para una cierta fecha.</li>
#     <li>hydrogen - Precio del hidrógeno para una cierta fecha.</li>
# </ul>

# %% [markdown]
# Una vez explicada los diferentes datos que se pueden encontrar en cada csv, se va a crear una tabla con solamente las variables importantes para esta investigación.

# %%
#df_gasoline_00_fechas = df_gasoline_00["date"].dropna()

# %%
# df_gasoline_00_fechas

# %%
# OPCIONAL

years = []
months = []
days = []
for k in df_gasoline_00_fechas:
    year, month, day = k.split('-')
    years.append(year)
    months.append(month)
    days.append(day)

# %%
# df_gasoline_00_v1 = pd.DataFrame(zip(df_gasoline_00["station_id"], df_gasoline_00["region_name"], df_gasoline_00["province_name"], df_gasoline_00["address"], df_gasoline_00["schedule"], years, months, days), columns=['Id estación', 'Región', 'Provincia', 'Dirección', 'Calendar', 'Año', 'Mes', 'Día'])

# %%
# Se crea una tabla con solamente los datos que nos interesan
df_gasoline_00_v1 = df_gasoline_00[['station_id','region_name', 'municipality_name', 'date', 'gasoline_95E5',
       'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
       'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
       'biodiesel', 'hydrogen']].copy()

# %%
df_gasoline_00_v1.head()
# Out:
#    station_id           region_name   municipality_name        date  \
# 0        4368    Castilla la Mancha       Villarrobledo  2022-05-31
# 1        3468  Comunidad Valenciana          Torrevieja  2022-05-31
# 2        7229             Andalucia             Sevilla  2022-05-31
# 3        7421             Andalucia        Torremolinos  2022-05-31
# 4         726               Galicia  Vilanova de Arousa  2022-06-03
#
#    gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 0          1.959                    NaN             NaN          2.079
# 1          2.044                  2.104             NaN          2.176
# 2          1.999                    NaN             NaN          2.149
# 3          2.089                    NaN             NaN          2.239
# 4          2.159                    NaN             NaN          2.259
#
#    gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 0             NaN     1.879     1.459           1.969        NaN        NaN
# 1             NaN     1.899       NaN           1.965        NaN        NaN
# 2             NaN     1.859       NaN           1.939        NaN        NaN
# 3             NaN     1.929       NaN           2.019        NaN        NaN
# 4             NaN     1.979     1.619           2.019        NaN        NaN
#
#    hydrogen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %% [markdown]
# Una vez creada, se van a aplicar los filtros explicados con anterioridad, buscar datos en Madrid durante el año 2022.

# %%
# Se filtra por la columna "date" para dar con las tomas hechas en 2022
df_gasoline2022_00 = df_gasoline_00_v1[(df_gasoline_00_v1["date"].str.contains("2022"))]

# %%
# Se filtra por la columna "region_name" para dar con aquellas estaciones registradas en Madrid
df_madrid2022_00 = df_gasoline2022_00[(df_gasoline2022_00["region_name"]=="Madrid")]

# %%
df_madrid2022_00
# Out:
#          station_id region_name       municipality_name        date  \
# 13             4312      Madrid                  Madrid  2022-06-03
# 15             3201      Madrid                  Madrid  2022-06-01
# 77             3222      Madrid  Torrejón de la Calzada  2022-03-04
# 599            4600      Madrid                  Madrid  2022-03-25
# 702            4364      Madrid             Navacerrada  2022-02-25
# ...             ...         ...                     ...         ...
# 2782682       14740      Madrid       Daganzo de Arriba  2022-01-06
# 2944952       15154      Madrid       Torrejón de Ardoz  2022-01-06
# 2951159       15068      Madrid       Torrejón de Ardoz  2022-01-06
# 2952449       15068      Madrid       Torrejón de Ardoz  2022-01-07
# 2956738       15068      Madrid       Torrejón de Ardoz  2022-01-09
#
#          gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 13               2.169                  2.229             NaN            NaN
# 15               2.099                    NaN             NaN          2.269
# 77               1.739                  1.799             NaN            NaN
# 599              1.889                    NaN             NaN          2.029
# 702              1.664                  1.744             NaN          1.796
# ...                ...                    ...             ...            ...
# 2782682          1.459                    NaN             NaN            NaN
# 2944952          1.379                    NaN             NaN            NaN
# 2951159          1.379                    NaN             NaN            NaN
# 2952449          1.379                    NaN             NaN            NaN
# 2956738          1.379                    NaN             NaN            NaN
#
#          gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  \
# 13                  NaN     2.005       NaN           2.085        NaN
# 15                  NaN     1.959       NaN           2.049        NaN
# 77                  NaN     1.655       NaN           1.735        NaN
# 599                 NaN     1.919       NaN           1.999        NaN
# 702                 NaN     1.549       NaN           1.629        NaN
# ...                 ...       ...       ...             ...        ...
# 2782682             NaN     1.339       NaN           1.359        NaN
# 2944952             NaN     1.227       NaN           1.237        NaN
# 2951159             NaN     1.227       NaN             NaN        NaN
# 2952449             NaN     1.237       NaN             NaN        NaN
# 2956738             NaN     1.237       NaN             NaN        NaN
#
#          biodiesel  hydrogen
# 13             NaN       NaN
# 15             NaN       NaN
# 77             NaN       NaN
# 599            NaN       NaN
# 702            NaN       NaN
# ...            ...       ...
# 2782682        NaN       NaN
# 2944952        NaN       NaN
# 2951159        NaN       NaN
# 2952449        NaN       NaN
# 2956738        NaN       NaN
#
# [7431 rows x 15 columns]

# %% [markdown]
# La tabla resultante resulta ser mucho más pequeña comparada con la gran cantidad de datos hallados en el documento original. <br>
# Todas las tablas que resulten de la carga y filtrado de los ficheros csv originales se verán reducidos en gran número, que luego se unirán bajo una misma tabla para su posterior análisis.

# %% [markdown]
# Una vez explicada la organización seguida para la carga de los diferentes ficheros, las siguientes se realizarán de la misma manera, por lo que no se volverá a explicar lo detallado con anterioridad.

# %% [markdown]
# ## CSV 01

# %%
df_gasoline_01 = pd.read_csv('D:\IA\spanish_gas_prices_000000000001.csv')

# %%
df_gasoline_01.head()
# Out:
#    station_id       name                                      address  \
# 0         723     REPSOL           CARRETERA LA HERMIDA -MARCON KM. 3
# 1        2059  EVOLUTION                         CALLE INDUSTRIA, 371
# 2        2573     REPSOL           CARRETERA C-711 PALMA-SOLLER KM. 7
# 3        1356         Q8  CARRETERA AVDA/ FUERZAS ARMADAS S/N KM. S/N
# 4        4859     REPSOL                          AUTOVIA A-2 KM. 107
#
#                         town  zip_code  longitude   latitude road_side  \
# 0                  PINO BORA     36154  -8.600306  42.422333         D
# 1  BADALONA                       8912   2.238417  41.436889         N
# 2  PALMA                          7120   2.663583  39.629778         D
# 3  CALATAYUD                     50300  -1.630278  41.353083         I
# 4  MIRABUENO                     19268  -2.714167  40.927722         D
#
#   restriction sender  ... gasoline_98E10  diesel_A  diesel_B  diesel_premium  \
# 0           P     dm  ...            NaN     1.939       NaN           1.989
# 1           P     dm  ...            NaN     1.837       NaN           1.867
# 2           P     dm  ...            NaN     1.955       NaN           2.025
# 3           P     dm  ...            NaN     1.799       NaN           1.869
# 4           P     dm  ...            NaN     1.959       NaN           2.009
#
#   bioetanol biodiesel lpg cng  lng  hydrogen
# 0       NaN       NaN NaN NaN  NaN       NaN
# 1       NaN       NaN NaN NaN  NaN       NaN
# 2       NaN       NaN NaN NaN  NaN       NaN
# 3       NaN       NaN NaN NaN  NaN       NaN
# 4       NaN       NaN NaN NaN  NaN       NaN
#
# [5 rows x 32 columns]

# %%
# Se crea una tabla con solamente los datos que nos interesan
df_gasoline_01_v1 = df_gasoline_01[['station_id','region_name', 'municipality_name', 'date', 'gasoline_95E5',
       'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
       'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
       'biodiesel', 'hydrogen']].copy()

# %%
df_gasoline_01_v1.head()
# Out:
#    station_id         region_name  municipality_name        date  \
# 0         723             Galicia         Pontevedra  2022-05-31
# 1        2059            Cataluña           Badalona  2022-06-01
# 2        2573            Baleares  Palma de Mallorca  2022-05-31
# 3        1356              Aragón          Calatayud  2022-05-31
# 4        4859  Castilla la Mancha          Mirabueno  2022-06-02
#
#    gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 0          2.069                    NaN             NaN          2.199
# 1          1.878                    NaN             NaN          1.995
# 2          2.099                    NaN             NaN          2.249
# 3          1.899                    NaN             NaN            NaN
# 4          2.099                    NaN             NaN            NaN
#
#    gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 0             NaN     1.939       NaN           1.989        NaN        NaN
# 1             NaN     1.837       NaN           1.867        NaN        NaN
# 2             NaN     1.955       NaN           2.025        NaN        NaN
# 3             NaN     1.799       NaN           1.869        NaN        NaN
# 4             NaN     1.959       NaN           2.009        NaN        NaN
#
#    hydrogen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Se filtra por la columna "date" para dar con las tomas hechas en 2022
df_gasoline2022_01 = df_gasoline_01_v1[df_gasoline_01_v1["date"].str.contains("2022")]

# %%
# Se filtra por la columna "region_name" para dar con aquellas estaciones registradas en Madrid
df_madrid2022_01 = df_gasoline2022_01[(df_gasoline2022_01["region_name"]=="Madrid")]

# %%
df_madrid2022_01
# Out:
#          station_id region_name  municipality_name        date  gasoline_95E5  \
# 12             4563      Madrid             Madrid  2022-06-02          2.139
# 314            9441      Madrid             Madrid  2022-02-28          1.679
# 930            4711      Madrid             Madrid  2022-01-06          1.579
# 1194           3091      Madrid      Navas del Rey  2022-03-05          1.724
# 1401           4586      Madrid             Madrid  2022-04-24          1.869
# ...             ...         ...                ...         ...            ...
# 2952616       14728      Madrid  Torrejón de Ardoz  2022-01-04          1.379
# 2954070       15161      Madrid  Torrejón de Ardoz  2022-01-03          1.379
# 2956087       15068      Madrid  Torrejón de Ardoz  2022-01-04          1.379
# 2956298       14070      Madrid        Tres Cantos  2022-01-23          1.379
# 2956367       15068      Madrid  Torrejón de Ardoz  2022-01-05          1.379
#
#          gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  gasoline_98E10  \
# 12                         NaN             NaN            NaN             NaN
# 314                        NaN             NaN          1.829             NaN
# 930                        NaN             NaN          1.704             NaN
# 1194                       NaN             NaN          1.844             NaN
# 1401                       NaN             NaN          2.019             NaN
# ...                        ...             ...            ...             ...
# 2952616                    NaN             NaN            NaN             NaN
# 2954070                    NaN             NaN            NaN             NaN
# 2956087                    NaN             NaN            NaN             NaN
# 2956298                    NaN             NaN            NaN             NaN
# 2956367                    NaN             NaN            NaN             NaN
#
#          diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  hydrogen
# 12          1.979       NaN           2.069        NaN        NaN       NaN
# 314         1.559       NaN           1.589        NaN        NaN       NaN
# 930         1.429       NaN           1.497        NaN        NaN       NaN
# 1194        1.649       NaN           1.719        NaN        NaN       NaN
# 1401        1.919       NaN           2.009        NaN        NaN       NaN
# ...           ...       ...             ...        ...        ...       ...
# 2952616     1.229       NaN             NaN        NaN        NaN       NaN
# 2954070     1.227       NaN             NaN        NaN        NaN       NaN
# 2956087     1.227       NaN             NaN        NaN        NaN       NaN
# 2956298     1.239       NaN             NaN        NaN        NaN       NaN
# 2956367     1.227       NaN             NaN        NaN        NaN       NaN
#
# [7203 rows x 15 columns]

# %% [markdown]
# ## CSV 02

# %%
df_gasoline_02 = pd.read_csv('D:\IA\spanish_gas_prices_000000000002.csv')

# %%
# Se crea una tabla con solamente los datos que nos interesan
df_gasoline_02_v1 = df_gasoline_02[['station_id','region_name', 'municipality_name', 'date', 'gasoline_95E5',
       'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
       'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
       'biodiesel', 'hydrogen']].copy()

# %%
df_gasoline_02_v1.head()
# Out:
#    station_id           region_name municipality_name        date  \
# 0        2994              Cataluña            Mataró  2022-06-03
# 1        2560              Cataluña             Olost  2022-06-03
# 2       12323  Comunidad Valenciana      Alcúdia (l')  2022-06-03
# 3        6839             Andalucia          Tabernas  2022-06-03
# 4        4673                Madrid  Sevilla la Nueva  2022-06-03
#
#    gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 0          2.159                    NaN             NaN          2.319
# 1          2.119                    NaN             NaN            NaN
# 2          1.889                    NaN             NaN            NaN
# 3          2.089                    NaN             NaN          2.239
# 4          2.104                    NaN             NaN          2.224
#
#    gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 0             NaN     1.999       NaN           2.069        NaN        NaN
# 1             NaN     1.969       NaN           2.029        NaN        NaN
# 2             NaN     1.849       NaN           1.909        NaN        NaN
# 3             NaN     1.949       NaN           2.039        NaN        NaN
# 4             NaN     1.984       NaN           2.054        NaN        NaN
#
#    hydrogen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Se filtra por la columna "date" para dar con las tomas hechas en 2022
df_gasoline2022_02 = df_gasoline_02_v1[df_gasoline_02_v1["date"].str.contains("2022")]

# %%
# Se filtra por la columna "region_name" para dar con aquellas estaciones registradas en Madrid
df_madrid2022_02 = df_gasoline2022_02[(df_gasoline2022_02["region_name"]=="Madrid")]

# %%
df_madrid2022_02.head()
# Out:
#      station_id region_name           municipality_name        date  \
# 4          4673      Madrid            Sevilla la Nueva  2022-06-03
# 24         4358      Madrid  San Sebastián de los Reyes  2022-06-01
# 242        2928      Madrid                  Villamanta  2022-03-16
# 255        4531      Madrid                      Madrid  2022-01-25
# 418        4578      Madrid         Buitrago del Lozoya  2022-04-18
#
#      gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 4            2.104                    NaN             NaN          2.224
# 24           2.099                    NaN             NaN          2.249
# 242          1.889                    NaN             NaN          2.031
# 255          1.589                    NaN             NaN          1.729
# 418          1.839                    NaN             NaN          1.969
#
#      gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 4               NaN     1.984       NaN           2.054        NaN        NaN
# 24              NaN     1.949       NaN           2.039        NaN        NaN
# 242             NaN     1.879       NaN           1.969        NaN        NaN
# 255             NaN     1.479       NaN           1.569        NaN        NaN
# 418             NaN     1.869       NaN           1.951        NaN        NaN
#
#      hydrogen
# 4         NaN
# 24        NaN
# 242       NaN
# 255       NaN
# 418       NaN

# %% [markdown]
# ## CSV 03

# %%
df_gasoline_03 = pd.read_csv('D:\IA\spanish_gas_prices_000000000003.csv')

# %%
# Se crea una tabla con solamente los datos que nos interesan
df_gasoline_03_v1 = df_gasoline_03[['station_id','region_name', 'municipality_name', 'date', 'gasoline_95E5',
       'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
       'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
       'biodiesel', 'hydrogen']].copy()

# %%
df_gasoline_03_v1.head()
# Out:
#    station_id           region_name  \
# 0       13063  Comunidad Valenciana
# 1        7413             Andalucia
# 2        9798            Rioja (La)
# 3        2697              Baleares
# 4        4093  Comunidad Valenciana
#
#                             municipality_name        date  gasoline_95E5  \
# 0  Castellón de la Plana/Castelló de la Plana  2022-06-01          2.079
# 1                                     Sevilla  2022-06-03          2.129
# 2                                     Logroño  2022-06-03          1.995
# 3                       Santa Eulalia del Río  2022-05-31          2.139
# 4                                    Valencia  2022-06-01          2.119
#
#    gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  gasoline_98E10  \
# 0                    NaN             NaN          2.221             NaN
# 1                    NaN             NaN          2.249             NaN
# 2                    NaN             NaN          2.091             NaN
# 3                    NaN             NaN            NaN             NaN
# 4                    NaN             NaN          2.229             NaN
#
#    diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  hydrogen
# 0     1.899       NaN           1.989        NaN        NaN       NaN
# 1     1.969       NaN           2.069        NaN        NaN       NaN
# 2     1.824       NaN           1.851        NaN        NaN       NaN
# 3     1.985       NaN           2.085        NaN        NaN       NaN
# 4     1.935       NaN           2.025        NaN        NaN       NaN

# %%
# Se filtra por la columna "date" para dar con las tomas hechas en 2022
df_gasoline2022_03 = df_gasoline_03_v1[df_gasoline_03_v1["date"].str.contains("2022")]

# %%
# Se filtra por la columna "region_name" para dar con aquellas estaciones registradas en Madrid
df_madrid2022_03 = df_gasoline2022_03[(df_gasoline2022_03["region_name"]=="Madrid")]

# %%
df_madrid2022_03.head()
# Out:
#      station_id region_name           municipality_name        date  \
# 21         4358      Madrid  San Sebastián de los Reyes  2022-06-02
# 50        11722      Madrid                      Madrid  2022-01-23
# 182        2916      Madrid                      Madrid  2022-02-16
# 219        3208      Madrid       Pezuela de las Torres  2022-04-10
# 619        4609      Madrid                    Móstoles  2022-03-25
#
#      gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 21           2.119                    NaN             NaN          2.269
# 50           1.629                    NaN             NaN          1.779
# 182          1.659                    NaN             NaN          1.769
# 219          1.769                    NaN             NaN            NaN
# 619          1.859                    NaN             NaN            NaN
#
#      gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 21              NaN     1.969       NaN           2.059        NaN        NaN
# 50              NaN     1.519       NaN           1.569        NaN        NaN
# 182             NaN     1.549       NaN           1.599        NaN        NaN
# 219             NaN     1.809       NaN           1.859        NaN        NaN
# 619             NaN     1.929       NaN           1.999        NaN        NaN
#
#      hydrogen
# 21        NaN
# 50        NaN
# 182       NaN
# 219       NaN
# 619       NaN

# %% [markdown]
# ## CSV 04

# %%
df_gasoline_04 = pd.read_csv('D:\IA\spanish_gas_prices_000000000004.csv')

# %%
# Se crea una tabla con solamente los datos que nos interesan
df_gasoline_04_v1 = df_gasoline_04[['station_id','region_name', 'municipality_name', 'date', 'gasoline_95E5',
       'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
       'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
       'biodiesel', 'hydrogen']].copy()

# %%
df_gasoline_04_v1.head()
# Out:
#    station_id         region_name  municipality_name        date  \
# 0        8500             Galicia               Vigo  2022-05-31
# 1         529             Galicia            Carnota  2022-06-03
# 2        5181  Castilla la Mancha  Valverde de Júcar  2022-06-01
# 3        1502              Aragón          Calatorao  2022-05-31
# 4        6648           Andalucia      Nueva Carteya  2022-06-02
#
#    gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 0          2.099                    NaN             NaN          2.209
# 1          2.169                  2.199             NaN            NaN
# 2          2.070                    NaN             NaN            NaN
# 3          2.059                    NaN             NaN            NaN
# 4          1.949                    NaN             NaN            NaN
#
#    gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 0             NaN     1.939       NaN           1.999        NaN        NaN
# 1             NaN     1.969       NaN           1.979        NaN        NaN
# 2             NaN     2.000     1.600           2.060        NaN        NaN
# 3             NaN     1.899       NaN           1.989        NaN        NaN
# 4             NaN     1.859     1.459           1.889        NaN        NaN
#
#    hydrogen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Se filtra por la columna "date" para dar con las tomas hechas en 2022
df_gasoline2022_04 = df_gasoline_04_v1[df_gasoline_04_v1["date"].str.contains("2022")]

# %%
# Se filtra por la columna "region_name" para dar con aquellas estaciones registradas en Madrid
df_madrid2022_04 = df_gasoline2022_04[(df_gasoline2022_04["region_name"]=="Madrid")]

# %%
df_madrid2022_04.head()
# Out:
#      station_id region_name        municipality_name        date  \
# 10         8464      Madrid  Villanueva de la Cañada  2022-06-02
# 40        11025      Madrid                   Madrid  2022-06-01
# 63        11344      Madrid                   Madrid  2022-04-03
# 77         2928      Madrid               Villamanta  2022-05-02
# 310        8058      Madrid   Velilla de San Antonio  2022-05-06
#
#      gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 10           2.079                    NaN             NaN          2.219
# 40           2.124                  2.184             NaN            NaN
# 63           1.829                    NaN             NaN          1.969
# 77           1.909                    NaN             NaN          2.051
# 310          1.919                    NaN             NaN          2.051
#
#      gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 10              NaN     1.939       NaN           2.019        NaN        NaN
# 40              NaN     1.959       NaN           2.039        NaN        NaN
# 63              NaN     1.869       NaN           1.949        NaN        NaN
# 77              NaN     1.989       NaN           2.079        NaN        NaN
# 310             NaN     1.985       NaN           2.065        NaN        NaN
#
#      hydrogen
# 10        NaN
# 40        NaN
# 63        NaN
# 77        NaN
# 310       NaN

# %% [markdown]
# ## CSV 05

# %%
df_gasoline_05 = pd.read_csv('D:\IA\spanish_gas_prices_000000000005.csv')

# %%
# Se crea una tabla con solamente los datos que nos interesan
df_gasoline_05_v1 = df_gasoline_05[['station_id','region_name', 'municipality_name', 'date', 'gasoline_95E5',
       'gasoline_95E5_premium', 'gasoline_95E10', 'gasoline_98E5',
       'gasoline_98E10', 'diesel_A', 'diesel_B', 'diesel_premium', 'bioetanol',
       'biodiesel', 'hydrogen']].copy()

# %%
df_gasoline_05_v1.head()
# Out:
#    station_id           region_name  municipality_name        date  \
# 0         418             Cantabria  Campoo de Enmedio  2022-06-01
# 1        7266             Andalucia              Écija  2022-06-03
# 2        5147    Castilla la Mancha             Cuenca  2022-06-01
# 3        3269              Cataluña            Tortosa  2022-06-02
# 4        4030  Comunidad Valenciana             Cheste  2022-06-03
#
#    gasoline_95E5  gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  \
# 0          2.019                    NaN             NaN          2.189
# 1          2.119                    NaN             NaN            NaN
# 2          2.089                    NaN             NaN          2.239
# 3          2.129                    NaN             NaN          2.279
# 4          1.840                    NaN             NaN          1.900
#
#    gasoline_98E10  diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  \
# 0             NaN     1.899     1.417           1.969        NaN        NaN
# 1             NaN     1.929     1.609           1.999        NaN        NaN
# 2             NaN     1.949       NaN           2.039        NaN        NaN
# 3             NaN     1.959       NaN           2.009        NaN        NaN
# 4             NaN     1.790     1.390           1.830        NaN        NaN
#
#    hydrogen
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
# Se filtra por la columna "date" para dar con las tomas hechas en 2022
df_gasoline2022_05 = df_gasoline_05_v1[df_gasoline_05_v1["date"].str.contains("2022")]

# %%
# Se filtra por la columna "region_name" para dar con aquellas estaciones registradas en Madrid
df_madrid2022_05 = df_gasoline2022_05[(df_gasoline2022_05["region_name"]=="Madrid")]

# %%
df_madrid2022_05.head()
# Out:
#      station_id region_name      municipality_name        date  gasoline_95E5  \
# 13         4661      Madrid  Rozas de Madrid (Las)  2022-06-02          2.109
# 28         3134      Madrid                 Getafe  2022-06-02          2.099
# 352       11746      Madrid                 Madrid  2022-04-14          1.819
# 451        4568      Madrid                Loeches  2022-04-08          1.799
# 604       12333      Madrid                  Pinto  2022-02-10          1.639
#
#      gasoline_95E5_premium  gasoline_95E10  gasoline_98E5  gasoline_98E10  \
# 13                     NaN             NaN          2.279             NaN
# 28                     NaN             NaN          2.241             NaN
# 352                    NaN             NaN          1.959             NaN
# 451                    NaN             NaN          1.949             NaN
# 604                    NaN             NaN          1.779             NaN
#
#      diesel_A  diesel_B  diesel_premium  bioetanol  biodiesel  hydrogen
# 13      1.979       NaN           2.019        NaN        NaN       NaN
# 28      1.979       NaN           2.069        NaN        NaN       NaN
# 352     1.849     1.522           1.899        NaN        NaN       NaN
# 451     1.859       NaN           1.909        NaN        NaN       NaN
# 604     1.539       NaN           1.629        NaN        NaN       NaN
